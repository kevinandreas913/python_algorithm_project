# %% [markdown]
# # PERBANDINGAN SARIMA, REGRESI LINEAR, DAN HYBRID SARIMA-REGERSI LINEAR

# %% [markdown]
# ## DAFTAR ISI
# ## 1. SARIMA MODEL WITHOUT  LINEAR REGRESSION (2022)
# ## 2. HYBIRD - SARIMA MODEL PREDICTIONS FOR THE NEXT 12 MONTH (2022)
# ## 3. LINEAR REGRESSION WITHOUT SARIMA MODEL (2022)
# ## 4. HYBRID - LINEAR REGRESSION PREDICTION THE NEXT 12 MONTH (2022)
# ## 5. HYBRID MODEL - SARIMA AND LINEAR REGRESSION FOR PREDICTION DATA 2023

# %% [markdown]
# # KETERANGAN:
# ## 1 = Data tersedia 2018 - 2022, menggunakan data 2018-2020 untuk learning model sarima kemudian prediksi tahun 2022. Hasil perdiksi kemudian dibandingkan dengan data asli tahun 2022 dan hitung MAE, MSE, dan MAPE.
# ## 3 = Data tersedia 2018 - 2022, menggunakan data 2018-2021, data tanggal dijadikan sebagai parameter x dan hasil dijadikan sebagai parameter y dan dilakukan learning menggunakan regresi linear. Kemudian, prediksi tahun 2022. Hasil perdiksi kemudian dibandingkan dengan data asli tahun 2022 dan hitung MAE, MSE, dan MAPE.
# ## 2,4 = Data tersedia 2018-2023, menggunakan data 2018-2021 untuk learning sarima dan dihasilkan prediksi 2022. Hasil prediksi SARIMA dijadikan sebagai parameter x dan data asli 2022 dijadikan parameter y dan dilakukan learning dengan target y. Mencoba nilai MAE, MSE, dan MAPE pada setiap bagian (SARIMA, regresi linear).
# ## 5 = Hasil model learning SARIMA (2) dan regresi linear (4) dijadikan sebagai dasar untuk prediksi tahun 2023. Hasil prediksi kemudian dibandingkan dengan data asli 2023 dan dilakukan perhitungan nilai MAE, MSE, dan MAPE.

# %%
import numpy as np  
import pandas as pd 
import matplotlib.pyplot as plt 
from statsmodels.tsa.statespace.sarimax import SARIMAX 
from statsmodels.tsa.stattools import adfuller 
from sklearn.metrics import mean_absolute_error, mean_squared_error
from pmdarima import auto_arima
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_percentage_error, r2_score
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Penggunaan data

# %%
df = pd.read_csv("energy.csv", sep=";")
display(df)

# Mengubah format data
# Fungsi id_vars untuk membaca baris
# Fungsi var_name untuk membaca kolom
# Fungsi value_name untuk membaca hasil
pisahdata = df.melt(id_vars=['Bulan'], var_name='Tahun', value_name='Energy')

# Mengubah kolom data sebelumnya yang sudah kita buat menjadi satu data tanggal yang utuh
pisahdata['Tanggal'] = pd.to_datetime(pisahdata['Tahun'] + ' ' + pisahdata['Bulan'])
# print(pisahdata)

# Mengatur Tanggal sebagai indeks dan memilih kolom yang relevan
dataku = pisahdata.set_index('Tanggal')[['Energy']]
# Out:
#         Bulan      2018      2019      2020      2021      2022
# 0     January  1243,195  1209,151  1027,701  1111,847  1199,616
# 1    February   880,913  1028,385    918,48  1093,345  1011,264
# 2       March   848,217   896,743   686,724   751,054   774,766
# 3       April   601,966   474,946   517,627   477,763   530,778
# 4         May   283,234   339,634   361,961   334,087   323,563
# 5        June   218,942   236,825   230,453   225,299   228,963
# 6        July   204,685   218,346   203,562   201,003   207,791
# 7      August     195,2   218,824    192,36   190,936   196,792
# 8   September   212,637   212,721   221,604   213,842   218,583
# 9     October   402,538   367,246   360,286   312,492   376,542
# 10   November     793,9    790,16   582,293   639,897   677,929
# 11   December  1000,361   982,315   993,271   858,382  1048,013
# C:\Users\Acer\AppData\Local\Temp\ipykernel_17796\3075555518.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pisahdata['Tanggal'] = pd.to_datetime(pisahdata['Tahun'] + ' ' + pisahdata['Bulan'])

# %%
jumlahdata = len(dataku)-12
datakulearning = dataku[:jumlahdata]
display(datakulearning)
# Out:
#               Energy
# Tanggal
# 2018-01-01  1243,195
# 2018-02-01   880,913
# 2018-03-01   848,217
# 2018-04-01   601,966
# 2018-05-01   283,234
# 2018-06-01   218,942
# 2018-07-01   204,685
# 2018-08-01     195,2
# 2018-09-01   212,637
# 2018-10-01   402,538
# 2018-11-01     793,9
# 2018-12-01  1000,361
# 2019-01-01  1209,151
# 2019-02-01  1028,385
# 2019-03-01   896,743
# 2019-04-01   474,946
# 2019-05-01   339,634
# 2019-06-01   236,825
# 2019-07-01   218,346
# 2019-08-01   218,824
# 2019-09-01   212,721
# 2019-10-01   367,246
# 2019-11-01    790,16
# 2019-12-01   982,315
# 2020-01-01  1027,701
# 2020-02-01    918,48
# 2020-03-01   686,724
# 2020-04-01   517,627
# 2020-05-01   361,961
# 2020-06-01   230,453
# 2020-07-01   203,562
# 2020-08-01    192,36
# 2020-09-01   221,604
# 2020-10-01   360,286
# 2020-11-01   582,293
# 2020-12-01   993,271
# 2021-01-01  1111,847
# 2021-02-01  1093,345
# 2021-03-01   751,054
# 2021-04-01   477,763
# 2021-05-01   334,087
# 2021-06-01   225,299
# 2021-07-01   201,003
# 2021-08-01   190,936
# 2021-09-01   213,842
# 2021-10-01   312,492
# 2021-11-01   639,897
# 2021-12-01   858,382

# %% [markdown]
# ### Visualisasikan data bulanan

# %%
# Membuat grafik dengan matplotlib
plt.figure(figsize=(12, 6))
plt.plot(datakulearning.index, datakulearning['Energy'], label='Energy', color='blue')

# Menambahkan judul dan label sumbu
plt.title('Grafik Penjualan (Sales) dari Waktu ke Waktu')
plt.xlabel('Tanggal')
plt.ylabel('Sales')
plt.xticks(rotation=45)

# Menambahkan grid dan legenda
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()

# Menampilkan grafik
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Uji Statistioner

# %% [markdown]
# Langkah ini untuk menguji apakah data sudah statistik atau belum:
# - Kalau datanya stasioner, artinya polanya tidak berubah terlalu banyak dari waktu ke waktu. Misalnya, penjualan naik atau turun tetapi rata-rata dan bentuk grafiknya tetap sama sepanjang waktu.
# - Kalau datanya tidak stasioner, maka grafiknya bisa naik terus, turun terus, atau punya pola yang berubah-ubah, misalnya lebih tinggi di bulan tertentu dan lebih rendah di bulan lainnya.
#
# Cara uji statistioner dapat dilakukan secara langsung dengan melihat grafiknya, tetapi ada juga penggunaan rumus untuk melihat apakah data sudah statistioner atau belum yaitu menggunakan teknik Augmented Dickey-Fuller (ADF).
#
# ### Hasil Uji:
#
# Hasil uji menggunakan metode ADF sama seperti uji statistik, semakin ADF statictik jauh dari 0 maka data tersebut semakin stabil.
#
# Hasil uji tersebut terbagi menjadi:
# - jika p-value < 0,05 => data hasil uji stabil (Stationary)
# - jika p-value > 0,05 => data hasil uji tidak stabil (Non Stationeary)
#
# Selain itu, melihat dari data "Staionary" juga lebih baik. Nilai hasil "Stationary" harus lebih kecil dari nilai ADF, semakin kecil, menunjukkan data statisioner

# %%
def check_stationarity(timeseries): 
    result = adfuller(timeseries, autolag='AIC') 
    p_value = result[1]
    print(f'ADF Statistic: {result[0]}') 
    print(f'p-value: {p_value}') 
    print(f'Statisioner: {result[4]}')
    if p_value < 0.05:
        Stasioner = 'stasioner'
    else:
        Stasioner = 'Non-stasioner'
    print(f'Disimpulkan berdasarkan analsisi ADF, P-Value, dan statisioner maka, hasilnya adalah {Stasioner}' )

# Menghapus tanda koma dan mengubah tipe data menjadi float
dataku['Energy'] = dataku['Energy'].str.replace(',', '.').astype(float)

check_stationarity(dataku['Energy'])
# Out:
# ADF Statistic: -1.2461139324201702
# p-value: 0.6534509701026923
# Statisioner: {'1%': -3.5745892596209488, '5%': -2.9239543084490744, '10%': -2.6000391840277777}
# Disimpulkan berdasarkan analsisi ADF, P-Value, dan statisioner maka, hasilnya adalah Non-stasioner

# %% [markdown]
# # SARIMA MODEL WITHOUT  LINEAR REGRESSION (2022)

# %% [markdown]
# ### Tentukan Parameter SARIMA
# Tentukan parameter uji dan test

# %%
train_size = int(len(dataku) * 1)
train, test = dataku[:train_size], dataku[train_size:]

# %%
model_auto = auto_arima(train, seasonal=True, m=12, stepwise=True, trace=True)
print(model_auto.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=inf, Time=0.44 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=561.406, Time=0.02 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=555.552, Time=0.29 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=0.35 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=559.433, Time=0.03 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=562.815, Time=0.11 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=555.707, Time=0.71 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=0.63 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=inf, Time=0.48 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=0.93 sec
#  ARIMA(0,0,0)(1,1,0)[12] intercept   : AIC=553.736, Time=0.17 sec
#  ARIMA(0,0,0)(2,1,0)[12] intercept   : AIC=553.710, Time=0.47 sec
#  ARIMA(0,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=0.77 sec
#  ARIMA(0,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=0.55 sec
#  ARIMA(0,0,1)(2,1,0)[12] intercept   : AIC=555.707, Time=0.51 sec
#  ARIMA(1,0,1)(2,1,0)[12] intercept   : AIC=557.710, Time=0.54 sec
#  ARIMA(0,0,0)(2,1,0)[12]             : AIC=552.767, Time=0.22 sec
#  ARIMA(0,0,0)(1,1,0)[12]             : AIC=552.273, Time=0.09 sec
#  ARIMA(0,0,0)(1,1,1)[12]             : AIC=inf, Time=0.17 sec
#  ARIMA(0,0,0)(0,1,1)[12]             : AIC=548.893, Time=0.11 sec
#  ARIMA(0,0,0)(0,1,2)[12]             : AIC=inf, Time=0.41 sec
#  ARIMA(0,0,0)(1,1,2)[12]             : AIC=inf, Time=0.72 sec
#  ARIMA(1,0,0)(0,1,1)[12]             : AIC=550.830, Time=0.24 sec
#  ARIMA(0,0,1)(0,1,1)[12]             : AIC=550.836, Time=0.18 sec
#  ARIMA(1,0,1)(0,1,1)[12]             : AIC=552.567, Time=0.44 sec
#  ARIMA(0,0,0)(0,1,1)[12] intercept   : AIC=inf, Time=0.26 sec
#
# Best model:  ARIMA(0,0,0)(0,1,1)[12]
# Total fit time: 9.896 seconds
#                                  SARIMAX Results
# ==================================================================================
# Dep. Variable:                          y   No. Observations:                   60
# Model:             SARIMAX(0, 1, [1], 12)   Log Likelihood                -272.447
# Date:                    Tue, 14 Jan 2025   AIC                            548.893
# Time:                            20:37:29   BIC                            552.636
# Sample:                        01-01-2018   HQIC                           550.307
#                              - 12-01-2022
# Covariance Type:                      opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.S.L12      -0.7827      0.441     -1.774      0.076      -1.648       0.082
# sigma2      4052.6051   1507.356      2.689      0.007    1098.242    7006.969
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                11.31
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.42   Skew:                            -0.70
# Prob(H) (two-sided):                  0.10   Kurtosis:                         4.93
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ## Pada SARIMA, kita mengenal:
# ### p
# - p menunjukkan model akan "menggunakan berapa data bulan ke belakang untuk memprediksi bulan depan". Semakin besar p, semakin banyak bulan yang dilihat.
#
# ### d
# - d adalah “differencing” untuk menghilangkan tren.
# - Bayangkan kamu punya data penjualan yang setiap bulan cenderung selalu naik terus menerus. d ini berfungsi untuk mengurangi atau menghilangkan tren kenaikan tersebut supaya datanya jadi lebih stabil dan tidak terlalu miring ke atas atau ke bawah.
# - Cara kerja: Misalnya, kalau d=1, kita mengurangi setiap nilai dengan nilai sebelumnya. Jadi, kalau bulan ini penjualannya naik dari bulan sebelumnya, kita cuma lihat selisihnya, bukan jumlah totalnya.
# - Gunanya: Untuk menghilangkan tren naik atau turun yang konsisten
#
# ### q
# - q mirip dengan p, tetapi pada q melihat kesalahan model dari bulan-bulan sebelumnya, jadi kalau ada salah di satu bulan, model bisa belajar dari kesalahan itu.
#
# ### P
# - memiliki fungsi yang sama dengan p, tetapi pada P melihat pola tahunan
#
# ### D
# - D adalah “differencing” untuk menghilangkan pola musiman.
# - Ini bekerja pada pola yang berulang setiap musim. Misalnya, jika penjualan selalu naik di akhir tahun, itu adalah pola musiman tahunan.
# - D membantu menghilangkan pola berulang ini dengan membandingkan nilai saat ini dengan nilai yang sama di musim sebelumnya. Jika musimnya tahunan dan data bulanan, maka kita bandingkan nilai sekarang dengan nilai 12 bulan sebelumnya.
# - Contoh: Kalau D=1, kita akan melihat perbedaan nilai penjualan dengan nilai satu tahun sebelumnya (12 bulan lalu).
#
# ### Q
# - Q mirip dengan q, tetapi pada Q melihat pola tahunan.
#
# ### S
# - s adalah jumlah bulan dalam satu musim. Kalau data kamu bulanan dan pola musimnya tahunan, maka s=12.

# %%
p, d, q = model_auto.order
P, D, Q, s = model_auto.seasonal_order  

# p, d, q = 1,0,0
# P, D, Q, s = 1,0,0,12

# %% [markdown]
# ### Prediksi bulan sebelumnya dan menilai dengan mape mae dan mse

# %%
train_data = dataku[:-12]
test_data = dataku[-12:]
Periode = 12
print(f"""ini adalah train data 
{train_data}""")

# print(f"""ini adalah test data 
# {test_data}""")
model = SARIMAX(train_data, order=(p, d, q), seasonal_order=(P, D, Q, s))
results = model.fit()

# Lakukan prediksi dengan eksogen masa depan
forecast = results.get_forecast(steps=Periode)

# forecast = results.get_forecast(steps=12)
predicted_mean = forecast.predicted_mean
confidence_interval = forecast.conf_int()

print("\nInterval Kepercayaan Prediksi (Lower, Upper):")
display(confidence_interval)

mae = mean_absolute_error(test_data, predicted_mean)
mse = mean_squared_error(test_data, predicted_mean)
# kedua teknik hidung mape ini adalah sama
mape2 = mean_absolute_percentage_error(test_data, predicted_mean) * 100
mape = np.mean(np.abs((test_data.values.flatten() - predicted_mean.values.flatten()) / test_data.values.flatten())) * 100
datates = test_data.reset_index()
print("test data:")
print(f"{datates}")

predict = pd.DataFrame(predicted_mean)
predict = predict.reset_index()
predict.rename(columns={"index":"Tanggal", "predicted_mean":"Hasil Prediksi"}, inplace=True)
# predict = predict.join(datates)
predict = pd.merge(datates, predict, on="Tanggal", how="inner")  # 'how="inner"' memastikan hanya tanggal yang cocok diambil

print(f"{predict}")

print(f'MAE: {mae}')
print(f'MSE: {mse}')
print(f'MAPE: {mape}%')
print("Nilai MAPE untuk Model Hybrid SARIMA adalah:", mape2, "%")

plt.figure(figsize=(12, 10)) 
plt.plot(dataku, label='Data Sebelumnya', color='black') 
plt.plot(predicted_mean, label='Prediksi', color='red') 
plt.fill_between(confidence_interval.index, confidence_interval.iloc[:, 0], confidence_interval.iloc[:, 1], color='pink') 
plt.title("Energy Forecast")
plt.xlabel("Date")
plt.ylabel("Income")
plt.legend()
plt.show()
# Out:
# ini adalah train data
#               Energy
# Tanggal
# 2018-01-01  1243.195
# 2018-02-01   880.913
# 2018-03-01   848.217
# 2018-04-01   601.966
# 2018-05-01   283.234
# 2018-06-01   218.942
# 2018-07-01   204.685
# 2018-08-01   195.200
# 2018-09-01   212.637
# 2018-10-01   402.538
# 2018-11-01   793.900
# 2018-12-01  1000.361
# 2019-01-01  1209.151
# 2019-02-01  1028.385
# 2019-03-01   896.743
# 2019-04-01   474.946
# 2019-05-01   339.634
# 2019-06-01   236.825
# 2019-07-01   218.346
# 2019-08-01   218.824
# 2019-09-01   212.721
# 2019-10-01   367.246
# 2019-11-01   790.160
# 2019-12-01   982.315
# 2020-01-01  1027.701
# 2020-02-01   918.480
# 2020-03-01   686.724
# 2020-04-01   517.627
# 2020-05-01   361.961
# 2020-06-01   230.453
# 2020-07-01   203.562
# 2020-08-01   192.360
# 2020-09-01   221.604
# 2020-10-01   360.286
# 2020-11-01   582.293
# 2020-12-01   993.271
# 2021-01-01  1111.847
# 2021-02-01  1093.345
# 2021-03-01   751.054
# 2021-04-01   477.763
# 2021-05-01   334.087
# 2021-06-01   225.299
# 2021-07-01   201.003
# 2021-08-01   190.936
# 2021-09-01   213.842
# 2021-10-01   312.492
# 2021-11-01   639.897
# 2021-12-01   858.382
#
# Interval Kepercayaan Prediksi (Lower, Upper):
# C:\Users\Acer\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\Acer\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\Acer\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#             lower Energy  upper Energy
# 2022-01-01    957.476275   1256.913199
# 2022-02-01    885.620721   1185.057645
# 2022-03-01    604.417838    903.854762
# 2022-04-01    343.113008    642.549932
# 2022-05-01    189.081146    488.518070
# 2022-06-01     77.578280    377.015204
# 2022-07-01     53.697255    353.134179
# 2022-08-01     44.391977    343.828901
# 2022-09-01     65.784756    365.221680
# 2022-10-01    183.601987    483.038911
# 2022-11-01    498.007781    797.444705
# 2022-12-01    759.213195   1058.650119
# test data:
#       Tanggal    Energy
# 0  2022-01-01  1199.616
# 1  2022-02-01  1011.264
# 2  2022-03-01   774.766
# 3  2022-04-01   530.778
# 4  2022-05-01   323.563
# 5  2022-06-01   228.963
# 6  2022-07-01   207.791
# 7  2022-08-01   196.792
# 8  2022-09-01   218.583
# 9  2022-10-01   376.542
# 10 2022-11-01   677.929
# 11 2022-12-01  1048.013
#       Tanggal    Energy  Hasil Prediksi
# 0  2022-01-01  1199.616     1107.194737
# 1  2022-02-01  1011.264     1035.339183
# 2  2022-03-01   774.766      754.136300
# 3  2022-04-01   530.778      492.831470
# 4  2022-05-01   323.563      338.799608
# 5  2022-06-01   228.963      227.296742
# 6  2022-07-01   207.791      203.415717
# 7  2022-08-01   196.792      194.110439
# 8  2022-09-01   218.583      215.503218
# 9  2022-10-01   376.542      333.320449
# 10 2022-11-01   677.929      647.726243
# 11 2022-12-01  1048.013      908.931657
# MAE: 34.55148493980918
# MSE: 2781.7922148460257
# MAPE: 4.951291769265896%
# Nilai MAPE untuk Model Hybrid SARIMA adalah: 4.951291769265896 %

# %% [markdown]
# # HYBIRD - SARIMA MODEL PREDICTIONS FOR THE NEXT 12 MONTH (2022)

# %% [markdown]
# ### Latih model SARIMA

# %%
model = SARIMAX(dataku, order=(p, d, q), seasonal_order=(P, D, Q, s)) 
# results = model.fit()
results2 = model.fit()
model
# Out:
# C:\Users\Acer\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\Acer\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\Acer\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'

# %% [markdown]
# ### Prediksi periode mendatang dengan sarima

# %%
Periode = 12

# Lakukan prediksi dengan eksogen masa depan
Prediksi = results2.get_forecast(steps=Periode)
Rata_Prediksi = Prediksi.predicted_mean
Confiden_Interval_Prediksi = Prediksi.conf_int()
print(Prediksi)
# Out:
# <statsmodels.tsa.statespace.mlemodel.PredictionResultsWrapper object at 0x000001BE4D05BF20>

# %%
# Menampilkan hasil prediksi
print("Rata-rata Prediksi Bulanan:")
display(Rata_Prediksi)

# Menampilkan interval kepercayaan untuk setiap prediksi
print("\nInterval Kepercayaan Prediksi (Lower, Upper):")
display(Confiden_Interval_Prediksi)
# Out:
# Rata-rata Prediksi Bulanan:
# 2023-01-01    1155.890613
# 2023-02-01     993.460117
# 2023-03-01     784.826798
# 2023-04-01     518.298027
# 2023-05-01     329.243080
# 2023-06-01     228.056586
# 2023-07-01     206.685304
# 2023-08-01     198.033972
# 2023-09-01     216.067716
# 2023-10-01     361.793198
# 2023-11-01     688.580447
# 2023-12-01     976.885825
# Freq: MS, Name: predicted_mean, dtype: float64
# Interval Kepercayaan Prediksi (Lower, Upper):
#             lower Energy  upper Energy
# 2023-01-01   1028.861233   1282.919992
# 2023-02-01    866.430737   1120.489496
# 2023-03-01    657.797418    911.856178
# 2023-04-01    391.268648    645.327407
# 2023-05-01    202.213700    456.272459
# 2023-06-01    101.027207    355.085966
# 2023-07-01     79.655924    333.714683
# 2023-08-01     71.004593    325.063352
# 2023-09-01     89.038336    343.097095
# 2023-10-01    234.763819    488.822578
# 2023-11-01    561.551067    815.609827
# 2023-12-01    849.856445   1103.915204

# %%
data2023 = pd.DataFrame([
1028.304,
903.434,
834.924,
486.767,
328.078,
240.926,
215.778,
204.16,
223.884,
363.424,
664.657,
861.584,

])
data2023.rename(columns={0:"data2023"}, inplace=True)

display(data2023)

mae = mean_absolute_error(Rata_Prediksi, data2023)
mse = mean_squared_error(Rata_Prediksi, data2023)
mape = mean_absolute_percentage_error(Rata_Prediksi, data2023) * 100
print(f'MAE: {mae}')
print(f'MSE: {mse}')
print(f'MAPE: {mape}%')

r_squared = r2_score(data2023, Rata_Prediksi)
r_value = np.sqrt(r_squared) 
if r_squared >= 0:
    r_value = np.sqrt(r_squared)
else:
    r_value = -np.sqrt(abs(r_squared))  # R-squared negatif, ambil nilai negatif
print("R-squared:", r_squared)
print("R-value (korelasi):", r_value)
# Out:
#     data2023
# 0   1028.304
# 1    903.434
# 2    834.924
# 3    486.767
# 4    328.078
# 5    240.926
# 6    215.778
# 7    204.160
# 8    223.884
# 9    363.424
# 10   664.657
# 11   861.584
# MAE: 39.763877827563256
# MSE: 3508.730104787826
# MAPE: 5.450154965074678%
# R-squared: 0.9603303464619738
# R-value (korelasi): 0.979964461836231

# %% [markdown]
# ### Hasil prediksi berdasarkan batas maximum dan minimum dan kepercayaan rata-rata

# %%
# Visualisasi dengan Interval Kepercayaan
plt.figure(figsize=(12, 6)) 
plt.plot(dataku, label='Data Sebelumnya', color='black') 
plt.plot(Rata_Prediksi, label='Prediksi', color='red') 
plt.fill_between(Confiden_Interval_Prediksi.index, Confiden_Interval_Prediksi.iloc[:, 0], Confiden_Interval_Prediksi.iloc[:, 1], color='pink', alpha=0.3) 
plt.title("Energy Forecast with Confidence Interval") 
plt.xlabel("Date") 
plt.ylabel("Income") 
plt.legend() 
plt.show()

# %% [markdown]
# # HYBRID - LINEAR REGRESSION PREDICTION THE NEXT 12 MONTH (2022)
#
# ## this section is linear regresion with assumptions we use sarima model before

# %% [markdown]
# ### Ini adalah data sebelumnya hasil dari sarima model prediksi 2022

# %%
display(predicted_mean)
display(test_data)
# Out:
# 2022-01-01    1107.194737
# 2022-02-01    1035.339183
# 2022-03-01     754.136300
# 2022-04-01     492.831470
# 2022-05-01     338.799608
# 2022-06-01     227.296742
# 2022-07-01     203.415717
# 2022-08-01     194.110439
# 2022-09-01     215.503218
# 2022-10-01     333.320449
# 2022-11-01     647.726243
# 2022-12-01     908.931657
# Freq: MS, Name: predicted_mean, dtype: float64
#               Energy
# Tanggal
# 2022-01-01  1199.616
# 2022-02-01  1011.264
# 2022-03-01   774.766
# 2022-04-01   530.778
# 2022-05-01   323.563
# 2022-06-01   228.963
# 2022-07-01   207.791
# 2022-08-01   196.792
# 2022-09-01   218.583
# 2022-10-01   376.542
# 2022-11-01   677.929
# 2022-12-01  1048.013

# %%
pred_sarima = Rata_Prediksi.values  # Hasil prediksi SARIMA
y_actual = dataku['Energy'][-12:].values  # Data aktual 12 bulan terakhir

# Persiapan data untuk Neural Network
X_train = pred_sarima.reshape(-1, 1)  # Gunakan prediksi SARIMA sebagai input
y_train = y_actual

mlp = MLPRegressor(hidden_layer_sizes=(50, 30), activation='relu', max_iter=500, random_state=42)
mlp.fit(X_train, y_train)

pred_residual_nn = mlp.predict(X_train)
print(y_actual)
print(pred_residual_nn)
# Out:
# [1199.616 1011.264  774.766  530.778  323.563  228.963  207.791  196.792
#   218.583  376.542  677.929 1048.013]
# [1203.44482773 1034.39203551  817.25273057  539.85757415  343.09485099
#   237.78298149  215.54039116  206.53634453  225.30532415  376.97203867
#   717.08241313 1017.14200944]

# %% [markdown]
# ### Hitung nilai MAE, MSE, dan MAPE

# %%
mae = mean_absolute_error(y_actual, pred_residual_nn)
mse = mean_squared_error(y_actual, pred_residual_nn)
mape = mean_absolute_percentage_error(y_actual, pred_residual_nn) * 100
print(f'MAE: {mae}')
print(f'MSE: {mse}')
print(f'MAPE: {mape}%')

data20222023 = pd.DataFrame([
1028.304,
903.434,
834.924,
486.767,
328.078,
240.926,
215.778,
204.16,
223.884,
363.424,
664.657,
861.584,

])
data20222023.rename(columns={0:"data2023"}, inplace=True)

r_squared = r2_score(y_actual, pred_residual_nn)
r_value = np.sqrt(r_squared) 
if r_squared >= 0:
    r_value = np.sqrt(r_squared)
else:
    r_value = -np.sqrt(abs(r_squared))  # R-squared negatif, ambil nilai negatif
print("R-squared:", r_squared)
print("R-value (korelasi):", r_value)
# Out:
# MAE: 16.79545855430793
# MSE: 465.2333227779656
# MAPE: 3.3567517141313625%
# R-squared: 0.9962354889005308
# R-value (korelasi): 0.9981159696651141

# %%
plt.figure(figsize=(12, 10)) 
plt.plot(predictlinearvalue['Tanggal'], predictlinearvalue['Energy'], label='Data Asli', color='black') 
plt.plot(predictlinearvalue['Tanggal'], predictlinearvalue['Prediksi Regresi Linear'], label='Prediksi', color='red') 
plt.title("Energy Forecast")
plt.xlabel("Date")
plt.ylabel("Income")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 plt.figure(figsize=(12, 10))
# ----> 2 plt.plot(predictlinearvalue['Tanggal'], predictlinearvalue['Energy'], label='Data Asli', color='black')
#       3 plt.plot(predictlinearvalue['Tanggal'], predictlinearvalue['Prediksi Regresi Linear'], label='Prediksi', color='red')
#       4 plt.title("Energy Forecast")
#
# NameError: name 'predictlinearvalue' is not defined

# %% [markdown]
# # HYBRID MODEL - SARIMA AND LINEAR REGRESSION FOR PREDICTION DATA 2023

# %% [markdown]
# ### Ini adalah data hasil prediksi sarima untuk tahun 2023 sebelumnya

# %%
print(Rata_Prediksi)
# Out:
# 2023-01-01    1155.890613
# 2023-02-01     993.460117
# 2023-03-01     784.826798
# 2023-04-01     518.298027
# 2023-05-01     329.243080
# 2023-06-01     228.056586
# 2023-07-01     206.685304
# 2023-08-01     198.033972
# 2023-09-01     216.067716
# 2023-10-01     361.793198
# 2023-11-01     688.580447
# 2023-12-01     976.885825
# Freq: MS, Name: predicted_mean, dtype: float64

# %% [markdown]
# ### Convert data menjadi pandas untuk siap dipakai dan berikan label

# %%
Rata_Prediksi_df = pd.DataFrame(Rata_Prediksi)
print(Rata_Prediksi_df)
# Out:
#             predicted_mean
# 2023-01-01     1155.890613
# 2023-02-01      993.460117
# 2023-03-01      784.826798
# 2023-04-01      518.298027
# 2023-05-01      329.243080
# 2023-06-01      228.056586
# 2023-07-01      206.685304
# 2023-08-01      198.033972
# 2023-09-01      216.067716
# 2023-10-01      361.793198
# 2023-11-01      688.580447
# 2023-12-01      976.885825

# %% [markdown]
# ### Gunakan model linear regresion untuk tahun 2022 sebelumnya untuk prediksi yang sekarang

# %%
prediksi_hybrid = mlp.predict(Rata_Prediksi_df)
print(prediksi_hybrid)
# Out:
# [1203.44482773 1034.39203551  817.25273057  539.85757415  343.09485099
#   237.78298149  215.54039116  206.53634453  225.30532415  376.97203867
#   717.08241313 1017.14200944]
# C:\Users\Acer\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(

# %% [markdown]
# ### Rapikan kembali data

# %%
Rata_Prediksi_df = Rata_Prediksi_df.reset_index().rename(columns={"index": "tanggal"})
Rata_Prediksi_df = Rata_Prediksi_df.drop(["predicted_mean"], axis=1)
print(Rata_Prediksi_df)

dfnewnew = pd.DataFrame(prediksi_hybrid)
dfnewnew.rename(columns={0: "Prediksi_12_bulan_mendatang"}, inplace=True)
print(dfnewnew)

combineprediksi = Rata_Prediksi_df.join(dfnewnew)
print(combineprediksi)
# Out:
#       tanggal
# 0  2023-01-01
# 1  2023-02-01
# 2  2023-03-01
# 3  2023-04-01
# 4  2023-05-01
# 5  2023-06-01
# 6  2023-07-01
# 7  2023-08-01
# 8  2023-09-01
# 9  2023-10-01
# 10 2023-11-01
# 11 2023-12-01
#     Prediksi_12_bulan_mendatang
# 0                   1203.444828
# 1                   1034.392036
# 2                    817.252731
# 3                    539.857574
# 4                    343.094851
# 5                    237.782981
# 6                    215.540391
# 7                    206.536345
# 8                    225.305324
# 9                    376.972039
# 10                   717.082413
# 11                  1017.142009
#       tanggal  Prediksi_12_bulan_mendatang
# 0  2023-01-01                  1203.444828
# 1  2023-02-01                  1034.392036
# 2  2023-03-01                   817.252731
# 3  2023-04-01                   539.857574
# 4  2023-05-01                   343.094851
# 5  2023-06-01                   237.782981
# 6  2023-07-01                   215.540391
# 7  2023-08-01                   206.536345
# 8  2023-09-01                   225.305324
# 9  2023-10-01                   376.972039
# 10 2023-11-01                   717.082413
# 11 2023-12-01                  1017.142009

# %% [markdown]
# ### Ambil data asli energi 2023 kemudian lakukan pengujian MAE, MSE, dan MAPE

# %%
data2023 = pd.DataFrame([
1028.304,
903.434,
834.924,
486.767,
328.078,
240.926,
215.778,
204.16,
223.884,
363.424,
664.657,
861.584,

])
data2023.rename(columns={0:"data2023"}, inplace=True)

display(data2023)

mae = mean_absolute_error(dfnewnew, data2023)
mse = mean_squared_error(dfnewnew, data2023)
mape = mean_absolute_percentage_error(dfnewnew, data2023) * 100
print(f'MAE: {mae}')
print(f'MSE: {mse}')
print(f'MAPE: {mape}%')

r_squared = r2_score(data2023, dfnewnew)
r_value = np.sqrt(r_squared) 
if r_squared >= 0:
    r_value = np.sqrt(r_squared)
else:
    r_value = -np.sqrt(abs(r_squared))  # R-squared negatif, ambil nilai negatif
print("R-squared:", r_squared)
print("R-value (korelasi):", r_value)
# Out:
#     data2023
# 0   1028.304
# 1    903.434
# 2    834.924
# 3    486.767
# 4    328.078
# 5    240.926
# 6    215.778
# 7    204.160
# 8    223.884
# 9    363.424
# 10   664.657
# 11   861.584
# MAE: 51.71560959005384
# MSE: 6527.3812529256365
# MAPE: 6.08324592899728%
# R-squared: 0.9262015187600685
# R-value (korelasi): 0.962393640232555

# %%
df = pd.read_csv("energy - Lengkap.csv", sep=";")
display(df)

# Mengubah format data
# Fungsi id_vars untuk membaca baris
# Fungsi var_name untuk membaca kolom
# Fungsi value_name untuk membaca hasil
pisahdata = df.melt(id_vars=['Bulan'], var_name='Tahun', value_name='Energy')

# Mengubah kolom data sebelumnya yang sudah kita buat menjadi satu data tanggal yang utuh
pisahdata['Tanggal'] = pd.to_datetime(pisahdata['Tahun'] + ' ' + pisahdata['Bulan'])
# print(pisahdata)

# Mengatur Tanggal sebagai indeks dan memilih kolom yang relevan
dataku = pisahdata.set_index('Tanggal')[['Energy']]
# Out:
#         Bulan      2018      2019      2020      2021      2022      2023
# 0     January  1243,195  1209,151  1027,701  1111,847  1199,616  1028,304
# 1    February   880,913  1028,385    918,48  1093,345  1011,264   903,434
# 2       March   848,217   896,743   686,724   751,054   774,766   834,924
# 3       April   601,966   474,946   517,627   477,763   530,778   486,767
# 4         May   283,234   339,634   361,961   334,087   323,563   328,078
# 5        June   218,942   236,825   230,453   225,299   228,963   240,926
# 6        July   204,685   218,346   203,562   201,003   207,791   215,778
# 7      August     195,2   218,824    192,36   190,936   196,792    204,16
# 8   September   212,637   212,721   221,604   213,842   218,583   223,884
# 9     October   402,538   367,246   360,286   312,492   376,542   363,424
# 10   November     793,9    790,16   582,293   639,897   677,929   664,657
# 11   December  1000,361   982,315   993,271   858,382  1048,013   861,584
# C:\Users\Acer\AppData\Local\Temp\ipykernel_17796\2198179813.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pisahdata['Tanggal'] = pd.to_datetime(pisahdata['Tahun'] + ' ' + pisahdata['Bulan'])

# %%
Rata_Prediksi_df['tanggal'] = pd.to_datetime(Rata_Prediksi_df['tanggal'])

# Visualisasi dengan Interval Kepercayaan
plt.figure(figsize=(12, 6)) 
plt.plot(dataku['Energy'], linewidth=3, label='Data Sebelumnya', color='black') 
plt.plot(Rata_Prediksi_df['tanggal'], Rata_Prediksi_df['coba'], label='Prediksi', color='red')
plt.fill_between(Confiden_Interval_Prediksi.index, Confiden_Interval_Prediksi.iloc[:, 0], Confiden_Interval_Prediksi.iloc[:, 1], color='pink', alpha=0.3) 

plt.title("Energy Forecast with Confidence Interval") 
plt.xlabel("Date") 
plt.ylabel("Income") 
plt.legend() 
plt.show()
