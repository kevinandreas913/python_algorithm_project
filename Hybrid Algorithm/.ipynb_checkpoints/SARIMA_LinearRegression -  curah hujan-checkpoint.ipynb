# %% [markdown]
# # PERBANDINGAN SARIMA, REGRESI LINEAR, DAN HYBRID SARIMA-REGERSI LINEAR

# %% [markdown]
# ## DAFTAR ISI
# ## 1. SARIMA MODEL WITHOUT  LINEAR REGRESSION (2022)
# ## 2. HYBIRD - SARIMA MODEL PREDICTIONS FOR THE NEXT 12 MONTH (2022)
# ## 3. LINEAR REGRESSION WITHOUT SARIMA MODEL (2022)
# ## 4. HYBRID - LINEAR REGRESSION PREDICTION THE NEXT 12 MONTH (2022)
# ## 5. HYBRID MODEL - SARIMA AND LINEAR REGRESSION FOR PREDICTION DATA 2023

# %% [markdown]
# # KETERANGAN:
# ## 1 = Data tersedia 2018 - 2022, menggunakan data 2018-2020 untuk learning model sarima kemudian prediksi tahun 2022. Hasil perdiksi kemudian dibandingkan dengan data asli tahun 2022 dan hitung MAE, MSE, dan MAPE.
# ## 3 = Data tersedia 2018 - 2022, menggunakan data 2018-2021, data tanggal dijadikan sebagai parameter x dan hasil dijadikan sebagai parameter y dan dilakukan learning menggunakan regresi linear. Kemudian, prediksi tahun 2022. Hasil perdiksi kemudian dibandingkan dengan data asli tahun 2022 dan hitung MAE, MSE, dan MAPE.
# ## 2,4 = Data tersedia 2018-2023, menggunakan data 2018-2021 untuk learning sarima dan dihasilkan prediksi 2022. Hasil prediksi SARIMA dijadikan sebagai parameter x dan data asli 2022 dijadikan parameter y dan dilakukan learning dengan target y. Mencoba nilai MAE, MSE, dan MAPE pada setiap bagian (SARIMA, regresi linear).
# ## 5 = Hasil model learning SARIMA (2) dan regresi linear (4) dijadikan sebagai dasar untuk prediksi tahun 2023. Hasil prediksi kemudian dibandingkan dengan data asli 2023 dan dilakukan perhitungan nilai MAE, MSE, dan MAPE.

# %%
import numpy as np  
import pandas as pd 
import matplotlib.pyplot as plt 
from statsmodels.tsa.statespace.sarimax import SARIMAX 
from statsmodels.tsa.stattools import adfuller 
from sklearn.metrics import mean_absolute_error, mean_squared_error
from pmdarima import auto_arima
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Penggunaan data

# %%
df = pd.read_csv("pajak.csv", sep=";")
display(df)

# Mengubah format data
# Fungsi id_vars untuk membaca baris
# Fungsi var_name untuk membaca kolom
# Fungsi value_name untuk membaca hasil
pisahdata = df.melt(id_vars=['Bulan'], var_name='Tahun', value_name='Sales')

# Mengubah kolom data sebelumnya yang sudah kita buat menjadi satu data tanggal yang utuh
pisahdata['Tanggal'] = pd.to_datetime(pisahdata['Tahun'] + ' ' + pisahdata['Bulan'])
# print(pisahdata)

# Mengatur Tanggal sebagai indeks dan memilih kolom yang relevan
dataku = pisahdata.set_index('Tanggal')[['Sales']]
# Out:
#         Bulan       2018        2019        2020        2021        2022
# 0     January  428119152   483090279   560460815   487507982   714711315
# 1    February  358130767   351465474   450423193   369572483   545246312
# 2       March  455039472   445098459   453376776   483872609   722084003
# 3       April  546156245   485731491   504703760   714210176  1367913715
# 4         May  474194889   522256203   459296096   588800941   857698769
# 5        June  502279900   424206413   386661052   496743778  1261493084
# 6        July  524512856   514622225   453400589   546429233   797613032
# 7      August  573518079   545657640   414006555   592896009   773320788
# 8   September  554237823   561839207   529957290   802721093   763264037
# 9     October  642066862   710376623   593982625   807867333   984403300
# 10   November  702228609   731362226   678349061   804631641   872766469
# 11   December  915114799  1012207070  1041255504  1286949680   872766469
# C:\Users\Acer\AppData\Local\Temp\ipykernel_3776\701712363.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pisahdata['Tanggal'] = pd.to_datetime(pisahdata['Tahun'] + ' ' + pisahdata['Bulan'])

# %%
jumlahdata = len(dataku)-12
datakulearning = dataku[:jumlahdata]
display(datakulearning)
# Out:
#                  Sales
# Tanggal
# 2018-01-01   428119152
# 2018-02-01   358130767
# 2018-03-01   455039472
# 2018-04-01   546156245
# 2018-05-01   474194889
# 2018-06-01   502279900
# 2018-07-01   524512856
# 2018-08-01   573518079
# 2018-09-01   554237823
# 2018-10-01   642066862
# 2018-11-01   702228609
# 2018-12-01   915114799
# 2019-01-01   483090279
# 2019-02-01   351465474
# 2019-03-01   445098459
# 2019-04-01   485731491
# 2019-05-01   522256203
# 2019-06-01   424206413
# 2019-07-01   514622225
# 2019-08-01   545657640
# 2019-09-01   561839207
# 2019-10-01   710376623
# 2019-11-01   731362226
# 2019-12-01  1012207070
# 2020-01-01   560460815
# 2020-02-01   450423193
# 2020-03-01   453376776
# 2020-04-01   504703760
# 2020-05-01   459296096
# 2020-06-01   386661052
# 2020-07-01   453400589
# 2020-08-01   414006555
# 2020-09-01   529957290
# 2020-10-01   593982625
# 2020-11-01   678349061
# 2020-12-01  1041255504
# 2021-01-01   487507982
# 2021-02-01   369572483
# 2021-03-01   483872609
# 2021-04-01   714210176
# 2021-05-01   588800941
# 2021-06-01   496743778
# 2021-07-01   546429233
# 2021-08-01   592896009
# 2021-09-01   802721093
# 2021-10-01   807867333
# 2021-11-01   804631641
# 2021-12-01  1286949680

# %% [markdown]
# ### Visualisasikan data bulanan

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 6)) 

# Menggambar garis penjualan
plt.plot(dataku['Sales'], linewidth=3, c='black') 

# Menambahkan titik pada setiap data penjualan
plt.scatter(dataku.index, dataku['Sales'], color='red', s=50, label='Sales Points', zorder=5) 

# Menambahkan tulisan nominal pada setiap titik
for i, value in enumerate(dataku['Sales']):
    plt.text(dataku.index[i], value, f'{value:.2f}', fontsize=9, ha='center', va='bottom')
    
plt.title("Grafik Penjualan") 
plt.xlabel("Date") 
plt.ylabel("Income") 
plt.legend()  # Menampilkan legend
plt.grid()  # Menambahkan grid untuk lebih jelas
plt.show()

# %% [markdown]
# ### Uji Statistioner

# %% [markdown]
# Langkah ini untuk menguji apakah data sudah statistik atau belum:
# - Kalau datanya stasioner, artinya polanya tidak berubah terlalu banyak dari waktu ke waktu. Misalnya, penjualan naik atau turun tetapi rata-rata dan bentuk grafiknya tetap sama sepanjang waktu.
# - Kalau datanya tidak stasioner, maka grafiknya bisa naik terus, turun terus, atau punya pola yang berubah-ubah, misalnya lebih tinggi di bulan tertentu dan lebih rendah di bulan lainnya.
#
# Cara uji statistioner dapat dilakukan secara langsung dengan melihat grafiknya, tetapi ada juga penggunaan rumus untuk melihat apakah data sudah statistioner atau belum yaitu menggunakan teknik Augmented Dickey-Fuller (ADF).
#
# ### Hasil Uji:
#
# Hasil uji menggunakan metode ADF sama seperti uji statistik, semakin ADF statictik jauh dari 0 maka data tersebut semakin stabil.
#
# Hasil uji tersebut terbagi menjadi:
# - jika p-value < 0,05 => data hasil uji stabil (Stationary)
# - jika p-value > 0,05 => data hasil uji tidak stabil (Non Stationeary)
#
# Selain itu, melihat dari data "Staionary" juga lebih baik. Nilai hasil "Stationary" harus lebih kecil dari nilai ADF, semakin kecil, menunjukkan data statisioner

# %%
def check_stationarity(timeseries): 
    result = adfuller(timeseries, autolag='AIC') 
    p_value = result[1]
    print(f'ADF Statistic: {result[0]}') 
    print(f'p-value: {p_value}') 
    print(f'Statisioner: {result[4]}')
    if p_value < 0.05:
        Stasioner = 'stasioner'
    else:
        Stasioner = 'Non-stasioner'
    print(f'Disimpulkan berdasarkan analsisi ADF, P-Value, dan statisioner maka, hasilnya adalah {Stasioner}' )
    

check_stationarity(dataku['Sales'])
# Out:
# ADF Statistic: 1.1050978616936666
# p-value: 0.9952598967514175
# Statisioner: {'1%': -3.5745892596209488, '5%': -2.9239543084490744, '10%': -2.6000391840277777}
# Disimpulkan berdasarkan analsisi ADF, P-Value, dan statisioner maka, hasilnya adalah Non-stasioner

# %% [markdown]
# # SARIMA MODEL WITHOUT  LINEAR REGRESSION (2022)

# %% [markdown]
# ### Tentukan Parameter SARIMA
# Tentukan parameter uji dan test

# %%
train_size = int(len(dataku) * 1)
train, test = dataku[:train_size], dataku[train_size:]

# %%
model_auto = auto_arima(train, seasonal=True, m=12, stepwise=True, trace=True)
print(model_auto.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=inf, Time=0.24 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=1919.248, Time=0.01 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=1916.150, Time=0.03 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=1916.577, Time=0.03 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=1914.165, Time=0.02 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=1916.151, Time=0.04 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=inf, Time=0.13 sec
#  ARIMA(2,1,0)(0,1,0)[12]             : AIC=1915.909, Time=0.02 sec
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=1915.712, Time=0.03 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=1914.578, Time=0.02 sec
#  ARIMA(2,1,1)(0,1,0)[12]             : AIC=1917.711, Time=0.06 sec
#  ARIMA(1,1,0)(0,1,0)[12] intercept   : AIC=1915.794, Time=0.02 sec
#
# Best model:  ARIMA(1,1,0)(0,1,0)[12]
# Total fit time: 0.678 seconds
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                   60
# Model:             SARIMAX(1, 1, 0)x(0, 1, 0, 12)   Log Likelihood                -955.083
# Date:                            Mon, 13 Jan 2025   AIC                           1914.165
# Time:                                    18:23:05   BIC                           1917.865
# Sample:                                01-01-2018   HQIC                          1915.557
#                                      - 12-01-2022
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2944      0.058     -5.111      0.000      -0.407      -0.181
# sigma2      2.301e+16   1.31e-21   1.75e+37      0.000     2.3e+16     2.3e+16
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.77   Jarque-Bera (JB):                10.64
# Prob(Q):                              0.18   Prob(JB):                         0.00
# Heteroskedasticity (H):               6.76   Skew:                            -0.26
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.27
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 6.04e+55. Standard errors may be unstable.

# %% [markdown]
# ## Pada SARIMA, kita mengenal:
# ### p
# - p menunjukkan model akan "menggunakan berapa data bulan ke belakang untuk memprediksi bulan depan". Semakin besar p, semakin banyak bulan yang dilihat.
#
# ### d
# - d adalah “differencing” untuk menghilangkan tren.
# - Bayangkan kamu punya data penjualan yang setiap bulan cenderung selalu naik terus menerus. d ini berfungsi untuk mengurangi atau menghilangkan tren kenaikan tersebut supaya datanya jadi lebih stabil dan tidak terlalu miring ke atas atau ke bawah.
# - Cara kerja: Misalnya, kalau d=1, kita mengurangi setiap nilai dengan nilai sebelumnya. Jadi, kalau bulan ini penjualannya naik dari bulan sebelumnya, kita cuma lihat selisihnya, bukan jumlah totalnya.
# - Gunanya: Untuk menghilangkan tren naik atau turun yang konsisten
#
# ### q
# - q mirip dengan p, tetapi pada q melihat kesalahan model dari bulan-bulan sebelumnya, jadi kalau ada salah di satu bulan, model bisa belajar dari kesalahan itu.
#
# ### P
# - memiliki fungsi yang sama dengan p, tetapi pada P melihat pola tahunan
#
# ### D
# - D adalah “differencing” untuk menghilangkan pola musiman.
# - Ini bekerja pada pola yang berulang setiap musim. Misalnya, jika penjualan selalu naik di akhir tahun, itu adalah pola musiman tahunan.
# - D membantu menghilangkan pola berulang ini dengan membandingkan nilai saat ini dengan nilai yang sama di musim sebelumnya. Jika musimnya tahunan dan data bulanan, maka kita bandingkan nilai sekarang dengan nilai 12 bulan sebelumnya.
# - Contoh: Kalau D=1, kita akan melihat perbedaan nilai penjualan dengan nilai satu tahun sebelumnya (12 bulan lalu).
#
# ### Q
# - Q mirip dengan q, tetapi pada Q melihat pola tahunan.
#
# ### S
# - s adalah jumlah bulan dalam satu musim. Kalau data kamu bulanan dan pola musimnya tahunan, maka s=12.

# %%
p, d, q = model_auto.order
P, D, Q, s = model_auto.seasonal_order  

# p, d, q = 1,0,0
# P, D, Q, s = 1,0,0,12

# %% [markdown]
# ### Prediksi bulan sebelumnya dan menilai dengan mape mae dan mse

# %%
train_data = dataku[:-12]
test_data = dataku[-12:]
Periode = 12
# print(f"""ini adalah train data 
# {train_data}""")

# print(f"""ini adalah test data 
# {test_data}""")
model = SARIMAX(train_data, order=(p, d, q), seasonal_order=(P, D, Q, s))
results = model.fit()

# Lakukan prediksi dengan eksogen masa depan
forecast = results.get_forecast(steps=Periode)

# forecast = results.get_forecast(steps=12)
predicted_mean = forecast.predicted_mean
confidence_interval = forecast.conf_int()

print("\nInterval Kepercayaan Prediksi (Lower, Upper):")
display(confidence_interval)

mae = mean_absolute_error(test_data, predicted_mean)
mse = mean_squared_error(test_data, predicted_mean)
# kedua teknik hidung mape ini adalah sama
mape2 = mean_absolute_percentage_error(test_data, predicted_mean) * 100
mape = np.mean(np.abs((test_data.values.flatten() - predicted_mean.values.flatten()) / test_data.values.flatten())) * 100
datates = test_data.reset_index()
print("test data:")
print(f"{datates}")

predict = pd.DataFrame(predicted_mean)
predict = predict.reset_index()
predict.rename(columns={"index":"Tanggal", "predicted_mean":"Hasil Prediksi"}, inplace=True)
# predict = predict.join(datates)
predict = pd.merge(datates, predict, on="Tanggal", how="inner")  # 'how="inner"' memastikan hanya tanggal yang cocok diambil

print(f"{predict}")

print(f'MAE: {mae}')
print(f'MSE: {mse}')
print(f'MAPE: {mape}%')
print("Nilai MAPE untuk Model Hybrid SARIMA adalah:", mape2, "%")

plt.figure(figsize=(12, 10)) 
plt.plot(dataku, label='Data Sebelumnya', color='black') 
plt.plot(predicted_mean, label='Prediksi', color='red') 
plt.fill_between(confidence_interval.index, confidence_interval.iloc[:, 0], confidence_interval.iloc[:, 1], color='pink') 
plt.title("Sales Forecast")
plt.xlabel("Date")
plt.ylabel("Income")
plt.legend()
plt.show()
# Out:
# Interval Kepercayaan Prediksi (Lower, Upper):
# C:\Users\Acer\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\Acer\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
#              lower Sales   upper Sales
# 2022-01-01  5.893335e+08  8.753988e+08
# 2022-02-01  4.128646e+08  8.160084e+08
# 2022-03-01  4.821477e+08  9.753256e+08
# 2022-04-01  6.745026e+08  1.243646e+09
# 2022-05-01  5.156149e+08  1.151715e+09
# 2022-06-01  3.932822e+08  1.089933e+09
# 2022-07-01  4.151210e+08  1.167466e+09
# 2022-08-01  4.356649e+08  1.239855e+09
# 2022-09-01  6.211401e+08  1.474030e+09
# 2022-10-01  6.032536e+08  1.502209e+09
# 2022-11-01  5.781093e+08  1.520882e+09
# 2022-12-01  1.039493e+09  2.024135e+09
# test data:
#       Tanggal       Sales
# 0  2022-01-01   714711315
# 1  2022-02-01   545246312
# 2  2022-03-01   722084003
# 3  2022-04-01  1367913715
# 4  2022-05-01   857698769
# 5  2022-06-01  1261493084
# 6  2022-07-01   797613032
# 7  2022-08-01   773320788
# 8  2022-09-01   763264037
# 9  2022-10-01   984403300
# 10 2022-11-01   872766469
# 11 2022-12-01   872766469
#       Tanggal       Sales  Hasil Prediksi
# 0  2022-01-01   714711315    7.323662e+08
# 1  2022-02-01   545246312    6.144365e+08
# 2  2022-03-01   722084003    7.287366e+08
# 3  2022-04-01  1367913715    9.590742e+08
# 4  2022-05-01   857698769    8.336649e+08
# 5  2022-06-01  1261493084    7.416078e+08
# 6  2022-07-01   797613032    7.912932e+08
# 7  2022-08-01   773320788    8.377600e+08
# 8  2022-09-01   763264037    1.047585e+09
# 9  2022-10-01   984403300    1.052731e+09
# 10 2022-11-01   872766469    1.049496e+09
# 11 2022-12-01   872766469    1.531814e+09
# MAE: 192120072.70157167
# MSE: 8.320227756280901e+16
# MAPE: 19.92180855732699%
# Nilai MAPE untuk Model Hybrid SARIMA adalah: 19.92180855732699 %

# %% [markdown]
# # HYBIRD - SARIMA MODEL PREDICTIONS FOR THE NEXT 12 MONTH (2022)

# %% [markdown]
# ### Latih model SARIMA

# %%
model = SARIMAX(dataku, order=(p, d, q), seasonal_order=(P, D, Q, s)) 
# results = model.fit()
results2 = model.fit()
model
# Out:
# C:\Users\Acer\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\Acer\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %% [markdown]
# ### Prediksi periode mendatang dengan sarima

# %%
Periode = 12

# Lakukan prediksi dengan eksogen masa depan
Prediksi = results2.get_forecast(steps=Periode)
Rata_Prediksi = Prediksi.predicted_mean
Confiden_Interval_Prediksi = Prediksi.conf_int()
print(Prediksi)
# Out:
# <statsmodels.tsa.statespace.mlemodel.PredictionResultsWrapper object at 0x000002B8D632DFA0>

# %%
# Menampilkan hasil prediksi
print("Rata-rata Prediksi Bulanan:")
display(Rata_Prediksi)

# Menampilkan interval kepercayaan untuk setiap prediksi
print("\nInterval Kepercayaan Prediksi (Lower, Upper):")
display(Confiden_Interval_Prediksi)
# Out:
# Rata-rata Prediksi Bulanan:
# 2023-01-01    4.425051e+08
# 2023-02-01    2.312472e+08
# 2023-03-01    4.203872e+08
# 2023-04-01    1.062596e+09
# 2023-05-01    5.534466e+08
# 2023-06-01    9.569272e+08
# 2023-07-01    4.931395e+08
# 2023-08-01    4.688201e+08
# 2023-09-01    4.587713e+08
# 2023-10-01    6.799082e+08
# 2023-11-01    5.682721e+08
# 2023-12-01    5.682719e+08
# Freq: MS, Name: predicted_mean, dtype: float64
# Interval Kepercayaan Prediksi (Lower, Upper):
#              lower Sales   upper Sales
# 2023-01-01  1.451945e+08  7.398158e+08
# 2023-02-01 -1.326302e+08  5.951247e+08
# 2023-03-01 -1.307906e+07  8.538535e+08
# 2023-04-01  5.728363e+08  1.552355e+09
# 2023-05-01  1.228304e+07  1.094610e+09
# 2023-06-01  3.690923e+08  1.544762e+09
# 2023-07-01 -1.379948e+08  1.124274e+09
# 2023-08-01 -2.028085e+08  1.140449e+09
# 2023-09-01 -2.510506e+08  1.168593e+09
# 2023-10-01 -6.615278e+07  1.425969e+09
# 2023-11-01 -2.123479e+08  1.348892e+09
# 2023-12-01 -2.454406e+08  1.381984e+09

# %% [markdown]
# ### Hasil prediksi berdasarkan batas maximum dan minimum dan kepercayaan rata-rata

# %%
# Visualisasi dengan Interval Kepercayaan
plt.figure(figsize=(12, 6)) 
plt.plot(dataku, label='Data Sebelumnya', color='black') 
plt.plot(Rata_Prediksi, label='Prediksi', color='red') 
plt.fill_between(Confiden_Interval_Prediksi.index, Confiden_Interval_Prediksi.iloc[:, 0], Confiden_Interval_Prediksi.iloc[:, 1], color='pink', alpha=0.3) 
plt.title("Sales Forecast with Confidence Interval") 
plt.xlabel("Date") 
plt.ylabel("Income") 
plt.legend() 
plt.show()

# %% [markdown]
# # LINEAR REGRESSION WITHOUT SARIMA MODEL (2022)

# %% [markdown]
# ### Ubah kolom tanggal menjadi format data lain
# ### Buang tahun 2022 karena akan dijadikan dasar dalam prediksi

# %%
linearregresion = dataku.reset_index()

linearregresion['Year'] = linearregresion['Tanggal'].dt.year
linearregresion['Month'] = linearregresion['Tanggal'].dt.month
linearregresion['dayofyear'] = linearregresion['Year'] + (linearregresion['Month'] - 1) / 12
linearregresionwithout2022 = linearregresion.drop(linearregresion.index[-12:])

# linearregresion['dayofyear'] = linearregresion['Tanggal'].dt.dayofyear
display(linearregresionwithout2022)

Xlinearregresiondayofyear = linearregresionwithout2022.drop(["Tanggal","Sales","Year","Month"], axis=1)
Ylinearregresionnominal = linearregresionwithout2022.drop(["Tanggal","dayofyear","Year","Month"], axis=1)
# Out:
#       Tanggal       Sales  Year  Month    dayofyear
# 0  2018-01-01   428119152  2018      1  2018.000000
# 1  2018-02-01   358130767  2018      2  2018.083333
# 2  2018-03-01   455039472  2018      3  2018.166667
# 3  2018-04-01   546156245  2018      4  2018.250000
# 4  2018-05-01   474194889  2018      5  2018.333333
# 5  2018-06-01   502279900  2018      6  2018.416667
# 6  2018-07-01   524512856  2018      7  2018.500000
# 7  2018-08-01   573518079  2018      8  2018.583333
# 8  2018-09-01   554237823  2018      9  2018.666667
# 9  2018-10-01   642066862  2018     10  2018.750000
# 10 2018-11-01   702228609  2018     11  2018.833333
# 11 2018-12-01   915114799  2018     12  2018.916667
# 12 2019-01-01   483090279  2019      1  2019.000000
# 13 2019-02-01   351465474  2019      2  2019.083333
# 14 2019-03-01   445098459  2019      3  2019.166667
# 15 2019-04-01   485731491  2019      4  2019.250000
# 16 2019-05-01   522256203  2019      5  2019.333333
# 17 2019-06-01   424206413  2019      6  2019.416667
# 18 2019-07-01   514622225  2019      7  2019.500000
# 19 2019-08-01   545657640  2019      8  2019.583333
# 20 2019-09-01   561839207  2019      9  2019.666667
# 21 2019-10-01   710376623  2019     10  2019.750000
# 22 2019-11-01   731362226  2019     11  2019.833333
# 23 2019-12-01  1012207070  2019     12  2019.916667
# 24 2020-01-01   560460815  2020      1  2020.000000
# 25 2020-02-01   450423193  2020      2  2020.083333
# 26 2020-03-01   453376776  2020      3  2020.166667
# 27 2020-04-01   504703760  2020      4  2020.250000
# 28 2020-05-01   459296096  2020      5  2020.333333
# 29 2020-06-01   386661052  2020      6  2020.416667
# 30 2020-07-01   453400589  2020      7  2020.500000
# 31 2020-08-01   414006555  2020      8  2020.583333
# 32 2020-09-01   529957290  2020      9  2020.666667
# 33 2020-10-01   593982625  2020     10  2020.750000
# 34 2020-11-01   678349061  2020     11  2020.833333
# 35 2020-12-01  1041255504  2020     12  2020.916667
# 36 2021-01-01   487507982  2021      1  2021.000000
# 37 2021-02-01   369572483  2021      2  2021.083333
# 38 2021-03-01   483872609  2021      3  2021.166667
# 39 2021-04-01   714210176  2021      4  2021.250000
# 40 2021-05-01   588800941  2021      5  2021.333333
# 41 2021-06-01   496743778  2021      6  2021.416667
# 42 2021-07-01   546429233  2021      7  2021.500000
# 43 2021-08-01   592896009  2021      8  2021.583333
# 44 2021-09-01   802721093  2021      9  2021.666667
# 45 2021-10-01   807867333  2021     10  2021.750000
# 46 2021-11-01   804631641  2021     11  2021.833333
# 47 2021-12-01  1286949680  2021     12  2021.916667

# %% [markdown]
# ### Buat model regresi linear dan latih dengan data yang telah disiapkan sebelumnya

# %%
model = LinearRegression()
model.fit(Xlinearregresiondayofyear, Ylinearregresionnominal)
# Out:
# LinearRegression()

# %% [markdown]
# ### Jadikan tahun 2022 sebagai target prediksi

# %%
linearregresionforpredict = linearregresion[-12:]
linearregresionforpredict = linearregresionforpredict.drop(["Tanggal","Sales","Year", "Month"], axis=1)
print(linearregresionforpredict)
# Out:
#       dayofyear
# 48  2022.000000
# 49  2022.083333
# 50  2022.166667
# 51  2022.250000
# 52  2022.333333
# 53  2022.416667
# 54  2022.500000
# 55  2022.583333
# 56  2022.666667
# 57  2022.750000
# 58  2022.833333
# 59  2022.916667

# %% [markdown]
# ### Latih model regresi linear yang telah dibangun

# %%
linearregresionvaluepredict = model.predict(linearregresionforpredict)
print(linearregresionvaluepredict)
# Out:
# [[7.01780901e+08]
#  [7.06639654e+08]
#  [7.11498408e+08]
#  [7.16357161e+08]
#  [7.21215915e+08]
#  [7.26074669e+08]
#  [7.30933422e+08]
#  [7.35792176e+08]
#  [7.40650929e+08]
#  [7.45509683e+08]
#  [7.50368436e+08]
#  [7.55227190e+08]]

# %% [markdown]
# ### Hitung nilai MAE, MSE, dan MAPE

# %%
Ylinearregresionnominal = Ylinearregresionnominal[-12:]
linearregresionvaluepredict = pd.DataFrame(linearregresionvaluepredict)
linearregresionvaluepredict.rename(columns={0:"prediksi"}, inplace=True)

mae = mean_absolute_error(Ylinearregresionnominal, linearregresionvaluepredict)
mse = mean_squared_error(Ylinearregresionnominal, linearregresionvaluepredict)
mape = mean_absolute_percentage_error(Ylinearregresionnominal, linearregresionvaluepredict) * 100
print(f'MAE: {mae}')
print(f'MSE: {mse}')
print(f'MAPE: {mape}%')
# Out:
# MAE: 181722716.91677475
# MSE: 5.2445604328216376e+16
# MAPE: 31.044552356520434%

# %% [markdown]
# # HYBRID - LINEAR REGRESSION PREDICTION THE NEXT 12 MONTH (2022)
#
# ## this section is linear regresion with assumptions we use sarima model before

# %% [markdown]
# ### Ini adalah data sebelumnya hasil dari sarima model prediksi 2022

# %%
display(predicted_mean)
display(test_data)
# Out:
# 2022-01-01    7.323662e+08
# 2022-02-01    6.144365e+08
# 2022-03-01    7.287366e+08
# 2022-04-01    9.590742e+08
# 2022-05-01    8.336649e+08
# 2022-06-01    7.416078e+08
# 2022-07-01    7.912932e+08
# 2022-08-01    8.377600e+08
# 2022-09-01    1.047585e+09
# 2022-10-01    1.052731e+09
# 2022-11-01    1.049496e+09
# 2022-12-01    1.531814e+09
# Freq: MS, Name: predicted_mean, dtype: float64
#                  Sales
# Tanggal
# 2022-01-01   714711315
# 2022-02-01   545246312
# 2022-03-01   722084003
# 2022-04-01  1367913715
# 2022-05-01   857698769
# 2022-06-01  1261493084
# 2022-07-01   797613032
# 2022-08-01   773320788
# 2022-09-01   763264037
# 2022-10-01   984403300
# 2022-11-01   872766469
# 2022-12-01   872766469

# %% [markdown]
# ### Gabungkan data menjadi data siap pakai

# %%
combined_data = test_data.join(predicted_mean)
combined_data = combined_data.reset_index()
print(combined_data)
# Out:
#       Tanggal       Sales  predicted_mean
# 0  2022-01-01   714711315    7.323662e+08
# 1  2022-02-01   545246312    6.144365e+08
# 2  2022-03-01   722084003    7.287366e+08
# 3  2022-04-01  1367913715    9.590742e+08
# 4  2022-05-01   857698769    8.336649e+08
# 5  2022-06-01  1261493084    7.416078e+08
# 6  2022-07-01   797613032    7.912932e+08
# 7  2022-08-01   773320788    8.377600e+08
# 8  2022-09-01   763264037    1.047585e+09
# 9  2022-10-01   984403300    1.052731e+09
# 10 2022-11-01   872766469    1.049496e+09
# 11 2022-12-01   872766469    1.531814e+09

# %% [markdown]
# ### Pisahkan data dan gunakan kolom sales sebagai parameter y (target) dan kolom predicted_mean sebagai parameter x

# %%
ylr = combined_data["Sales"]  # Target harus tetap 1D
xlr = combined_data[["predicted_mean"]] # Input harus 2D

# %% [markdown]
# ### Buat model regresi linear dan latih data dengan x dan y kemudian coba lakukan prediksi atas parameter x

# %%
model = LinearRegression()
model.fit(xlr, ylr)
lineartestvalue = model.predict(xlr)
print(lineartestvalue)
# Out:
# [8.42635337e+08 8.19313622e+08 8.41917557e+08 8.87469015e+08
#  8.62668139e+08 8.44462954e+08 8.54288728e+08 8.63477977e+08
#  9.04972895e+08 9.05990614e+08 9.05350724e+08 1.00073373e+09]

# %%
predictlinearvalue = pd.DataFrame(lineartestvalue)
predictlinearvalue = combined_data.join(predictlinearvalue)
predictlinearvalue.rename(columns={0:"Prediksi Regresi Linear"}, inplace=True)
predictlinearvalue = predictlinearvalue.drop(["predicted_mean"], axis=1)
print(predictlinearvalue)
# Out:
#       Tanggal       Sales  Prediksi Regresi Linear
# 0  2022-01-01   714711315             8.426353e+08
# 1  2022-02-01   545246312             8.193136e+08
# 2  2022-03-01   722084003             8.419176e+08
# 3  2022-04-01  1367913715             8.874690e+08
# 4  2022-05-01   857698769             8.626681e+08
# 5  2022-06-01  1261493084             8.444630e+08
# 6  2022-07-01   797613032             8.542887e+08
# 7  2022-08-01   773320788             8.634780e+08
# 8  2022-09-01   763264037             9.049729e+08
# 9  2022-10-01   984403300             9.059906e+08
# 10 2022-11-01   872766469             9.053507e+08
# 11 2022-12-01   872766469             1.000734e+09

# %% [markdown]
# ### Hitung nilai MAE, MSE, dan MAPE

# %%
mae = mean_absolute_error(ylr, lineartestvalue)
mse = mean_squared_error(ylr, lineartestvalue)
mape = mean_absolute_percentage_error(ylr, lineartestvalue) * 100
print(f'MAE: {mae}')
print(f'MSE: {mse}')
print(f'MAPE: {mape}%')
# Out:
# MAE: 162647919.5003059
# MSE: 4.713426814275066e+16
# MAPE: 18.10090309921523%

# %%
plt.figure(figsize=(12, 10)) 
plt.plot(predictlinearvalue['Tanggal'], predictlinearvalue['Sales'], label='Data Asli', color='black') 
plt.plot(predictlinearvalue['Tanggal'], predictlinearvalue['Prediksi Regresi Linear'], label='Prediksi', color='red') 
plt.title("Sales Forecast")
plt.xlabel("Date")
plt.ylabel("Income")
plt.legend()
plt.show()

# %% [markdown]
# # HYBRID MODEL - SARIMA AND LINEAR REGRESSION FOR PREDICTION DATA 2023

# %% [markdown]
# ### Ini adalah data hasil prediksi sarima untuk tahun 2023 sebelumnya

# %%
print(Rata_Prediksi)
# Out:
# 2023-01-01    4.425051e+08
# 2023-02-01    2.312472e+08
# 2023-03-01    4.203872e+08
# 2023-04-01    1.062596e+09
# 2023-05-01    5.534466e+08
# 2023-06-01    9.569272e+08
# 2023-07-01    4.931395e+08
# 2023-08-01    4.688201e+08
# 2023-09-01    4.587713e+08
# 2023-10-01    6.799082e+08
# 2023-11-01    5.682721e+08
# 2023-12-01    5.682719e+08
# Freq: MS, Name: predicted_mean, dtype: float64

# %% [markdown]
# ### Convert data menjadi pandas untuk siap dipakai dan berikan label

# %%
Rata_Prediksi_df = pd.DataFrame(Rata_Prediksi)
print(Rata_Prediksi_df)
# Out:
#             predicted_mean
# 2023-01-01    4.425051e+08
# 2023-02-01    2.312472e+08
# 2023-03-01    4.203872e+08
# 2023-04-01    1.062596e+09
# 2023-05-01    5.534466e+08
# 2023-06-01    9.569272e+08
# 2023-07-01    4.931395e+08
# 2023-08-01    4.688201e+08
# 2023-09-01    4.587713e+08
# 2023-10-01    6.799082e+08
# 2023-11-01    5.682721e+08
# 2023-12-01    5.682719e+08

# %% [markdown]
# ### Gunakan model linear regresion untuk tahun 2022 sebelumnya untuk prediksi yang sekarang

# %%
prediksi_hybrid = model.predict(Rata_Prediksi_df)
print(prediksi_hybrid)
# Out:
# [7.85312546e+08 7.43534269e+08 7.80938518e+08 9.07941363e+08
#  8.07252288e+08 8.87044422e+08 7.95325970e+08 7.90516569e+08
#  7.88529333e+08 8.32261272e+08 8.10184158e+08 8.10184118e+08]

# %%
Rata_Prediksi_df = pd.DataFrame(Rata_Prediksi_df) 
Rata_Prediksi_df["coba"] = (Rata_Prediksi_df['predicted_mean'].values*0.2)+(prediksi_hybrid*0.8)
print(Rata_Prediksi_df)
# Out:
#             predicted_mean          coba
# 2023-01-01    4.425051e+08  7.167511e+08
# 2023-02-01    2.312472e+08  6.410769e+08
# 2023-03-01    4.203872e+08  7.088283e+08
# 2023-04-01    1.062596e+09  9.388722e+08
# 2023-05-01    5.534466e+08  7.564912e+08
# 2023-06-01    9.569272e+08  9.010210e+08
# 2023-07-01    4.931395e+08  7.348887e+08
# 2023-08-01    4.688201e+08  7.261773e+08
# 2023-09-01    4.587713e+08  7.225777e+08
# 2023-10-01    6.799082e+08  8.017907e+08
# 2023-11-01    5.682721e+08  7.618017e+08
# 2023-12-01    5.682719e+08  7.618017e+08

# %% [markdown]
# ### Rapikan kembali data

# %%
Rata_Prediksi_df = Rata_Prediksi_df.reset_index().rename(columns={"index": "tanggal"})
Rata_Prediksi_df = Rata_Prediksi_df.drop(["predicted_mean"], axis=1)
print(Rata_Prediksi_df)

dfnewnew = pd.DataFrame(Rata_Prediksi_df)
dfnewnew = dfnewnew.drop(["tanggal"], axis =1)
print(dfnewnew)
# Out:
#       tanggal          coba
# 0  2023-01-01  7.167511e+08
# 1  2023-02-01  6.410769e+08
# 2  2023-03-01  7.088283e+08
# 3  2023-04-01  9.388722e+08
# 4  2023-05-01  7.564912e+08
# 5  2023-06-01  9.010210e+08
# 6  2023-07-01  7.348887e+08
# 7  2023-08-01  7.261773e+08
# 8  2023-09-01  7.225777e+08
# 9  2023-10-01  8.017907e+08
# 10 2023-11-01  7.618017e+08
# 11 2023-12-01  7.618017e+08
#             coba
# 0   7.167511e+08
# 1   6.410769e+08
# 2   7.088283e+08
# 3   9.388722e+08
# 4   7.564912e+08
# 5   9.010210e+08
# 6   7.348887e+08
# 7   7.261773e+08
# 8   7.225777e+08
# 9   8.017907e+08
# 10  7.618017e+08
# 11  7.618017e+08

# %% [markdown]
# ### Ambil data asli pajak 2023 kemudian lakukan pengujian MAE, MSE, dan MAPE

# %%
data2023 = pd.DataFrame([900796559,
633787375,
772481009,
991414194,
751398095,
749813878,
836354027,
838966661,
827910165,
975420672,
1028141172,
1464265000,
])
data2023.rename(columns={0:"data2023"}, inplace=True)

display(data2023)

mae = mean_absolute_error(dfnewnew, data2023)
mse = mean_squared_error(dfnewnew, data2023)
mape = mean_absolute_percentage_error(dfnewnew, data2023) * 100
print(f'MAE: {mae}')
print(f'MSE: {mse}')
print(f'MAPE: {mape}%')
# Out:
#       data2023
# 0    900796559
# 1    633787375
# 2    772481009
# 3    991414194
# 4    751398095
# 5    749813878
# 6    836354027
# 7    838966661
# 8    827910165
# 9    975420672
# 10  1028141172
# 11  1464265000
# MAE: 160487485.5734674
# MSE: 5.7689844229015976e+16
# MAPE: 20.965841167534286%

# %%
df = pd.read_csv("pajak - Lengkap.csv", sep=";")
display(df)

# Mengubah format data
# Fungsi id_vars untuk membaca baris
# Fungsi var_name untuk membaca kolom
# Fungsi value_name untuk membaca hasil
pisahdata = df.melt(id_vars=['Bulan'], var_name='Tahun', value_name='Sales')

# Mengubah kolom data sebelumnya yang sudah kita buat menjadi satu data tanggal yang utuh
pisahdata['Tanggal'] = pd.to_datetime(pisahdata['Tahun'] + ' ' + pisahdata['Bulan'])
# print(pisahdata)

# Mengatur Tanggal sebagai indeks dan memilih kolom yang relevan
dataku = pisahdata.set_index('Tanggal')[['Sales']]
# Out:
#         Bulan       2018        2019        2020        2021        2022  \
# 0     January  428119152   483090279   560460815   487507982   714711315
# 1    February  358130767   351465474   450423193   369572483   545246312
# 2       March  455039472   445098459   453376776   483872609   722084003
# 3       April  546156245   485731491   504703760   714210176  1367913715
# 4         May  474194889   522256203   459296096   588800941   857698769
# 5        June  502279900   424206413   386661052   496743778  1261493084
# 6        July  524512856   514622225   453400589   546429233   797613032
# 7      August  573518079   545657640   414006555   592896009   773320788
# 8   September  554237823   561839207   529957290   802721093   763264037
# 9     October  642066862   710376623   593982625   807867333   984403300
# 10   November  702228609   731362226   678349061   804631641   872766469
# 11   December  915114799  1012207070  1041255504  1286949680   872766469
#
#           2023
# 0    900796559
# 1    633787375
# 2    772481009
# 3    991414194
# 4    751398095
# 5    749813878
# 6    836354027
# 7    838966661
# 8    827910165
# 9    975420672
# 10  1028141172
# 11  1464265000
# C:\Users\Acer\AppData\Local\Temp\ipykernel_3776\3758713614.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pisahdata['Tanggal'] = pd.to_datetime(pisahdata['Tahun'] + ' ' + pisahdata['Bulan'])

# %%
Rata_Prediksi_df['tanggal'] = pd.to_datetime(Rata_Prediksi_df['tanggal'])

# Visualisasi dengan Interval Kepercayaan
plt.figure(figsize=(12, 6)) 
plt.plot(dataku['Sales'], linewidth=3, label='Data Sebelumnya', color='black') 
plt.plot(Rata_Prediksi_df['tanggal'], Rata_Prediksi_df['coba'], label='Prediksi', color='red')
plt.fill_between(Confiden_Interval_Prediksi.index, Confiden_Interval_Prediksi.iloc[:, 0], Confiden_Interval_Prediksi.iloc[:, 1], color='pink', alpha=0.3) 

plt.title("Sales Forecast with Confidence Interval") 
plt.xlabel("Date") 
plt.ylabel("Income") 
plt.legend() 
plt.show()
